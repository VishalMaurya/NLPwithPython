# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalMaurya/NLPwithPython/blob/master/Course/NLP_01_python_basic/Python_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # spaCy Basics
# spaCy (https://spacy.io/) is an open-source Python library that parses and "understands" large volumes of text. Separate models are available that cater to specific languages (English, French, German, etc.).

# %%
import numpy as np
import pandas as pd
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# create doc object
doc = nlp(u'Punjab CM Capt Amarinder Singh has invited President Ram Nath Kovind, Prime Minister Narendra Modi and former Prime Minister Manmohan Singh to join the first all-party group that would attend the historic event of the opening of Kartarpur Corridor in Pakistan.')

# %%
for token in doc:
  print(f'{token.text:{10}} {token.pos_:{10}} {token.dep_:{10}} {spacy.explain(token.dep_):}')
# Out:
# Punjab     PROPN      compound   compound
# CM         PROPN      compound   compound
# Capt       PROPN      compound   compound
# Amarinder  PROPN      compound   compound
# Singh      PROPN      nsubj      nominal subject
# has        VERB       aux        auxiliary
# invited    VERB       ROOT       None
# President  PROPN      compound   compound
# Ram        PROPN      compound   compound
# Nath       PROPN      compound   compound
# Kovind     PROPN      dobj       direct object
# ,          PUNCT      punct      punctuation
# Prime      PROPN      compound   compound
# Minister   PROPN      compound   compound
# Narendra   PROPN      compound   compound
# Modi       PROPN      conj       conjunct
# and        CCONJ      cc         coordinating conjunction
# former     ADJ        amod       adjectival modifier
# Prime      PROPN      compound   compound
# Minister   PROPN      compound   compound
# Manmohan   PROPN      compound   compound
# Singh      PROPN      conj       conjunct
# to         PART       aux        auxiliary
# join       VERB       xcomp      open clausal complement
# the        DET        det        determiner
# first      ADJ        amod       adjectival modifier
# all        DET        det        determiner
# -          PUNCT      punct      punctuation
# party      NOUN       compound   compound
# group      NOUN       dobj       direct object
# that       DET        nsubj      nominal subject
# would      VERB       aux        auxiliary
# attend     VERB       relcl      relative clause modifier
# the        DET        det        determiner
# historic   ADJ        amod       adjectival modifier
# event      NOUN       dobj       direct object
# of         ADP        prep       prepositional modifier
# the        DET        det        determiner
# opening    NOUN       pobj       object of preposition
# of         ADP        prep       prepositional modifier
# Kartarpur  PROPN      compound   compound
# Corridor   PROPN      pobj       object of preposition
# in         ADP        prep       prepositional modifier
# Pakistan   PROPN      pobj       object of preposition
# .          PUNCT      punct      punctuation

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7fa656c5ca90>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7fa656628708>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7fa656628768>)]

# %% [markdown]
# # Tokenization

# %%
for token in doc:
  print(f'{token.text:{10}} {token.tag_:{10}} {token.lemma_:{10}} {token.is_alpha:{10}} {spacy.explain(token.tag_):>{25}}')
# Out:
# Punjab     NNP        Punjab              1     noun, proper singular
# CM         NNP        CM                  1     noun, proper singular
# Capt       NNP        Capt                1     noun, proper singular
# Amarinder  NNP        Amarinder           1     noun, proper singular
# Singh      NNP        Singh               1     noun, proper singular
# has        VBZ        have                1 verb, 3rd person singular present
# invited    VBN        invite              1     verb, past participle
# President  NNP        President           1     noun, proper singular
# Ram        NNP        Ram                 1     noun, proper singular
# Nath       NNP        Nath                1     noun, proper singular
# Kovind     NNP        Kovind              1     noun, proper singular
# ,          ,          ,                   0   punctuation mark, comma
# Prime      NNP        Prime               1     noun, proper singular
# Minister   NNP        Minister            1     noun, proper singular
# Narendra   NNP        Narendra            1     noun, proper singular
# Modi       NNP        Modi                1     noun, proper singular
# and        CC         and                 1 conjunction, coordinating
# former     JJ         former              1                 adjective
# Prime      NNP        Prime               1     noun, proper singular
# Minister   NNP        Minister            1     noun, proper singular
# Manmohan   NNP        Manmohan            1     noun, proper singular
# Singh      NNP        Singh               1     noun, proper singular
# to         TO         to                  1            infinitival to
# join       VB         join                1           verb, base form
# the        DT         the                 1                determiner
# first      JJ         first               1                 adjective
# all        DT         all                 1                determiner
# -          HYPH       -                   0  punctuation mark, hyphen
# party      NN         party               1    noun, singular or mass
# group      NN         group               1    noun, singular or mass
# that       WDT        that                1             wh-determiner
# would      MD         would               1     verb, modal auxiliary
# attend     VB         attend              1           verb, base form
# the        DT         the                 1                determiner
# historic   JJ         historic            1                 adjective
# event      NN         event               1    noun, singular or mass
# of         IN         of                  1 conjunction, subordinating or preposition
# the        DT         the                 1                determiner
# opening    NN         opening             1    noun, singular or mass
# of         IN         of                  1 conjunction, subordinating or preposition
# Kartarpur  NNP        Kartarpur           1     noun, proper singular
# Corridor   NNP        Corridor            1     noun, proper singular
# in         IN         in                  1 conjunction, subordinating or preposition
# Pakistan   NNP        Pakistan            1     noun, proper singular
# .          .          .                   0 punctuation mark, sentence closer

# %%
doc2 = nlp(u'In nutshell, Pakistan came out of the cold to shoot itself in foot and give India yet another sweet victory.\
 The previous one for India was in the International Court of Justice (ICJ) which stayed execution of Kulbhushan Jadhav, the former Indian Navy officer, and ordered review of the judgment of a Pakistan military court.')
for sent in doc2.sents:
  print(sent)
# Out:
# In nutshell, Pakistan came out of the cold to shoot itself in foot and give India yet another sweet victory.
# The previous one for India was in the International Court of Justice (ICJ) which stayed execution of Kulbhushan Jadhav, the former Indian Navy officer, and ordered review of the judgment of a Pakistan military court.

# %%
span_doc = doc2[30:34]
span_doc
# Out:
# International Court of Justice

# %%
print(type(span_doc))
print(type(doc2))
# Out:
# <class 'spacy.tokens.span.Span'>
# <class 'spacy.tokens.doc.Doc'>

# %%
for entity in doc2.ents:
  print(entity) 
  print(entity.label_) 
  print(spacy.explain(entity.label_))
  print('\n')
# Out:
# Pakistan
# GPE
# Countries, cities, states
#
#
# India
# GPE
# Countries, cities, states
#
#
# India
# GPE
# Countries, cities, states
#
#
# the International Court of Justice
# ORG
# Companies, agencies, institutions, etc.
#
#
# ICJ
# ORG
# Companies, agencies, institutions, etc.
#
#
# Kulbhushan Jadhav
# PERSON
# People, including fictional
#
#
# Indian
# NORP
# Nationalities or religious or political groups
#
#
# Navy
# ORG
# Companies, agencies, institutions, etc.
#
#
# Pakistan
# GPE
# Countries, cities, states

# %%
for chunk in doc2.noun_chunks:
  print(chunk)
# Out:
# nutshell
# Pakistan
# the cold
# itself
# foot
# India
# yet another sweet victory
# The previous one
# India
# Justice
# execution
# Kulbhushan Jadhav
# the former Indian Navy officer
# review
# the judgment
# a Pakistan military court

# %%
spacy.displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">In nutshell,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  came out of the cold to shoot itself in foot and give
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  yet another sweet victory. The previous one for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the International Court of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ICJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) which stayed execution of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kulbhushan Jadhav
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Navy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  officer, and ordered review of the judgment of a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  military court.</div>

# %%
spacy.displacy.render(doc2, style='dep', jupyter=True, options={'distance':80})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="34e4e60ed4e84c868f305afbbc300f5d-0" class="displacy" width="4450" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">nutshell,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Pakistan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">came</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">cold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">shoot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">itself</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">foot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">give</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">yet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">sweet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">victory.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">previous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">International</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">Court</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displ

# %% [markdown]
# # Stemming

# %%
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
doc2
# Out:
# In nutshell, Pakistan came out of the cold to shoot itself in foot and give India yet another sweet victory. The previous one for India was in the International Court of Justice (ICJ) which stayed execution of Kulbhushan Jadhav, the former Indian Navy officer, and ordered review of the judgment of a Pakistan military court.

# %%
Porter = PorterStemmer()
Snowball = SnowballStemmer(language='english')
for token in doc2:
  print(token.text,'----->',Porter.stem(token.text),'|',Snowball.stem(token.text))
# Out:
# In -----> In | in
# nutshell -----> nutshel | nutshel
# , -----> , | ,
# Pakistan -----> pakistan | pakistan
# came -----> came | came
# out -----> out | out
# of -----> of | of
# the -----> the | the
# cold -----> cold | cold
# to -----> to | to
# shoot -----> shoot | shoot
# itself -----> itself | itself
# in -----> in | in
# foot -----> foot | foot
# and -----> and | and
# give -----> give | give
# India -----> india | india
# yet -----> yet | yet
# another -----> anoth | anoth
# sweet -----> sweet | sweet
# victory -----> victori | victori
# . -----> . | .
# The -----> the | the
# previous -----> previou | previous
# one -----> one | one
# for -----> for | for
# India -----> india | india
# was -----> wa | was
# in -----> in | in
# the -----> the | the
# International -----> intern | intern
# Court -----> court | court
# of -----> of | of
# Justice -----> justic | justic
# ( -----> ( | (
# ICJ -----> icj | icj
# ) -----> ) | )
# which -----> which | which
# stayed -----> stay | stay
# execution -----> execut | execut
# of -----> of | of
# Kulbhushan -----> kulbhushan | kulbhushan
# Jadhav -----> jadhav | jadhav
# , -----> , | ,
# the -----> the | the
# former -----> former | former
# Indian -----> indian | indian
# Navy -----> navi | navi
# officer -----> offic | offic
# , -----> , | ,
# and -----> and | and
# ordered -----> order | order
# review -----> review | review
# of -----> of | of
# the -----> the | the
# judgment -----> judgment | judgment
# of -----> of | of
# a -----> a | a
# Pakistan -----> pakistan | pakistan
# military -----> militari | militari
# court -----> court | court
# . -----> . | .

# %% [markdown]
# # Lemmatization

# %%
doc3 = nlp(u"I am a runner running in a race because I love to run since I ran today")

for token in doc3:
    print(token.text, '\t', token.pos_, '\t', token.lemma, '\t', token.lemma_)
# Out:
# I 	 PRON 	 561228191312463089 	 -PRON-
# am 	 VERB 	 10382539506755952630 	 be
# a 	 DET 	 11901859001352538922 	 a
# runner 	 NOUN 	 12640964157389618806 	 runner
# running 	 VERB 	 12767647472892411841 	 run
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 ADP 	 16950148841647037698 	 because
# I 	 PRON 	 561228191312463089 	 -PRON-
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 ADP 	 10066841407251338481 	 since
# I 	 PRON 	 561228191312463089 	 -PRON-
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %% [markdown]
# # Stopwords

# %%
# total number of stopwords in spaCy
(nlp.Defaults.stop_words)
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
word_list = ['ran', 'parsimonious', 'witch']
for word in word_list:
  print(nlp.vocab[word].is_stop)
# Out:
# False
# False
# False

# %%
 nlp.vocab['since'].is_stop
# Out:
# True

# %%
# add a new stop word
nlp.Defaults.stop_words.add('btw')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.Defaults.stop_words.remove('btw')

# %% [markdown]
# # Vocabulary & Matcher

# %%
from spacy.matcher import Matcher, PhraseMatcher

# word matching
matcher = Matcher(nlp.vocab)

# phrase matching
Pmathcer = PhraseMatcher(nlp.vocab)

# %%
doc5 = nlp(u'Solar-powered energy runs solar-powered cars.')

# %%
pattern = [{'LOWER': 'solar'}, {'IS_PUNCT': True, 'OP':'*'}, {'LOWER': 'powered', 'OP':'*'}]

# Add the new set of patterns to the 'SolarPower' matcher:
matcher.add('SolarPower', None, pattern)

# %%
matcher(doc5)
# Out:
# [(8656102463236116519, 0, 1),
#  (8656102463236116519, 0, 2),
#  (8656102463236116519, 0, 3),
#  (8656102463236116519, 5, 6),
#  (8656102463236116519, 5, 7),
#  (8656102463236116519, 5, 8)]
